# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,Flatten,Conv2D
from tensorflow.keras.layers import BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from IPython.display import SVG,Image
import tensorflow as tf
print("Tensorflow version: ",tf.__version__)
# Out:
# Tensorflow version:  2.15.0

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
train_validation = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor,filters,kernel_size):
    x = Conv2D(filters=filters,kernel_size =kernel_size,padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor,nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))

    flatten = Flatten()(conv_3)
    dense_1 = Dense_f(flatten,256)

    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs],outputs = [output])

    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam',metrics = ['accuracy'])
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **INITIALISING THE MODEL**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = train_validation.n//train_validation.batch_size

checkpoint = ModelCheckpoint("model_weight.h5",monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# **Training the Model**

# %% [markdown]
# **the next cell takes time to complete**

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = train_validation,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\envs\project\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6407 - accuracy: 0.3781
# Epoch 1: saving model to model_weight.h5
# 448/448 [==============================] - 689s 2s/step - loss: 1.6407 - accuracy: 0.3781 - val_loss: 1.5365 - val_accuracy: 0.4026
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3479 - accuracy: 0.4893
# Epoch 2: saving model to model_weight.h5
# 448/448 [==============================] - 208s 463ms/step - loss: 1.3479 - accuracy: 0.4893 - val_loss: 1.5096 - val_accuracy: 0.4177
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1886 - accuracy: 0.5566
# Epoch 3: saving model to model_weight.h5
# 448/448 [==============================] - 211s 470ms/step - loss: 1.1886 - accuracy: 0.5566 - val_loss: 1.5535 - val_accuracy: 0.4113
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0559 - accuracy: 0.6087
# Epoch 4: saving model to model_weight.h5
# 448/448 [==============================] - 203s 454ms/step - loss: 1.0559 - accuracy: 0.6087 - val_loss: 1.4827 - val_accuracy: 0.4512
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9349 - accuracy: 0.6584
# Epoch 5: saving model to model_weight.h5
# 448/448 [==============================] - 201s 448ms/step - loss: 0.9349 - accuracy: 0.6584 - val_loss: 1.6825 - val_accuracy: 0.4107
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8081 - accuracy: 0.7092
# Epoch 6: saving model to model_weight.h5
# 448/448 [==============================] - 199s 444ms/step - loss: 0.8081 - accuracy: 0.7092 - val_loss: 1.7076 - val_accuracy: 0.4160
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.7526
# Epoch 7: saving model to model_weight.h5
# 448/448 [==============================] - 200s 445ms/step - loss: 0.6945 - accuracy: 0.7526 - val_loss: 1.6145 - val_accuracy: 0.4736
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.7908
# Epoch 8: saving model to model_weight.h5
# 448/448 [==============================] - 198s 441ms/step - loss: 0.5961 - accuracy: 0.7908 - val_loss: 1.6104 - val_accuracy: 0.4778
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5059 - accuracy: 0.8252
# Epoch 9: saving model to model_weight.h5
# 448/448 [==============================] - 186s 414ms/step - loss: 0.5059 - accuracy: 0.8252 - val_loss: 1.6617 - val_accuracy: 0.4743
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.8532
# Epoch 10: saving model to model_weight.h5
# 448/448 [==============================] - 186s 414ms/step - loss: 0.4347 - accuracy: 0.8532 - val_loss: 1.7626 - val_accuracy: 0.4840
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8697
# Epoch 11: saving model to model_weight.h5
# 448/448 [==============================] - 189s 422ms/step - loss: 0.3827 - accuracy: 0.8697 - val_loss: 1.8211 - val_accuracy: 0.4675
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3321 - accuracy: 0.8872
# Epoch 12: saving model to model_weight.h5
# 448/448 [==============================] - 215s 479ms/step - loss: 0.3321 - accuracy: 0.8872 - val_loss: 1.7506 - val_accuracy: 0.4950
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8989
# Epoch 13: saving model to model_weight.h5
# 448/448 [==============================] - 215s 480ms/step - loss: 0.3060 - accuracy: 0.8989 - val_loss: 1.9193 - val_accuracy: 0.4721
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9109
# Epoch 14: saving model to model_weight.h5
# 448/448 [==============================] - 217s 485ms/step - loss: 0.2650 - accuracy: 0.9109 - val_loss: 1.9091 - val_accuracy: 0.4964
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9184
# Epoch 15: saving model to model_weight.h5
# 448/448 [==============================] - 196s 438ms/step - loss: 0.2442 - accuracy: 0.9184 - val_loss: 2.0737 - val_accuracy: 0.4650

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(train_validation)
# Out:
# 113/113 [==============================] - 13s 112ms/step - loss: 2.0742 - accuracy: 0.4649
# [2.0742247104644775, 0.464892715215683]

# %% [markdown]
# **PLOTTING LOSS**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **x is no of epoch y is loss**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving the Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
